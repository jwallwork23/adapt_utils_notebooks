# %% [markdown]
# This notebook shows that the continuous and discrete adjoint methods give the same result if no stabilisation is applied.

# %%
from firedrake import *
from firedrake_adjoint import *

# %%
import matplotlib.pyplot as plt
import scipy.interpolate as si

# %%
from adapt_utils.case_studies.tohoku.options.options import TohokuInversionOptions
from adapt_utils.misc import gaussian, ellipse

# %% [markdown]
# Specify 'optimum' and initial guess

# %%
m_opt = 5.0
m_prior = 10.0

# %% [markdown]
# Create `Options` object and setup gauges.

# %%
level = 3
op = TohokuInversionOptions(level=level)
gauges = list(op.gauges.keys())
for gauge in gauges:
    if gauge[:2] not in ('P0', '80'):
        op.gauges.pop(gauge)
gauges = list(op.gauges.keys())
# Out:
# /home/joe/software/firedrake-pragmatic/src/firedrake/firedrake/parloops.py:130: LoopyWarning: 'lang_version' was not passed to make_function(). To avoid this warning, pass lang_version=(2018, 2) in this invocation. (Or say 'from loopy.version import LOOPY_USE_LANGUAGE_VERSION_2018_2' in the global scope of the calling frame.)
#   knl = loopy.make_function(kernel_domains, instructions, kargs, seq_dependencies=True,

# %% [markdown]
# Setup timestepping parameters

# %%
num_timesteps = 30*2**level
dt = Constant(op.dt)
theta = Constant(0.5)

# %% [markdown]
# Create function spaces

# %%
mesh = op.default_mesh
P2 = VectorFunctionSpace(mesh, "CG", 1)
P1 = FunctionSpace(mesh, "CG", 1)
V = P2*P1
R = FunctionSpace(mesh, "R", 0)

# %% [markdown]
# Create `Function`s

# %%
u, eta = TrialFunctions(V)
test_u, test_eta = TestFunctions(V)
m = Function(R).assign(m_prior)
c = Control(m)
q0 = Function(V)
u0, eta0 = q0.split()
eta0.interpolate(gaussian([(0.7e+06, 4.2e+06, 48e+03, 96e+03)], mesh, rotation=pi/12))
q_ = Function(V)
u_, eta_ = q_.split();

# %% [markdown]
# Set physical parameters

# %%
b = Function(P1).assign(op.set_bathymetry(P1))
g = Constant(9.81)

# %% [markdown]
# Setup forward variational problem

# %%
a = inner(u, test_u)*dx + eta*test_eta*dx
a += theta*dt*g*inner(grad(eta), test_u)*dx - theta*dt*b*inner(u, grad(test_eta))*dx
L = inner(u_, test_u)*dx + eta_*test_eta*dx
L += -(1-theta)*dt*g*inner(grad(eta_), test_u)*dx + (1-theta)*dt*b*inner(u_, grad(test_eta))*dx
q = Function(V)
u, eta = q.split()
bc = DirichletBC(V.sub(1), 0, 100)
problem = LinearVariationalProblem(a, L, q, bcs=bc)

# %% [markdown]
# Setup forward variational solver

# %%
sp = {
    "snes_type": "ksponly",
    "ksp_type": "gmres",
    "pc_type": "fieldsplit",
    "pc_fieldsplit_type": "multiplicative",
}
solver = LinearVariationalSolver(problem, solver_parameters=sp)

# %% [markdown]
# Setup QoI

# %%
P0 = FunctionSpace(mesh, "DG", 0)
J_form = 0
radius = 20e+03*0.5**level
for gauge in gauges:
    op.gauges[gauge]["data"] = []
    k = Function(P0*P0)
    ku, keta = k.split()
    keta.interpolate(ellipse([op.gauges[gauge]["coords"] + (radius,)], mesh))
    keta.assign(keta/assemble(keta*dx))
    op.gauges[gauge]["indicator"] = keta
    op.gauges[gauge]["obs"] = Function(R)
    op.gauges[gauge]["obs_old"] = Function(R)
    J_form += theta*0.5*dt*keta*(eta - op.gauges[gauge]["obs"])**2*dx
    J_form += (1-theta)*0.5*dt*keta*(eta_ - op.gauges[gauge]["obs_old"])**2*dx

# %% [markdown]
# Solve forward to generate 'data'

# %%
u_.assign(u0)
eta_.project(m_opt*eta0)
for gauge in gauges:
    op.gauges[gauge]["data"].append(float(eta_.at(op.gauges[gauge]["coords"])))
for i in range(num_timesteps):
    print(f"t = {i*op.dt/60:5.1f} min  ||u|| = {norm(u):.4e}  ||eta|| = {norm(eta):.4e}")
    solver.solve()
    q_.assign(q)
    for gauge in gauges:
        op.gauges[gauge]["data"].append(float(eta.at(op.gauges[gauge]["coords"])))
print(f"t = {(i+1)*op.dt/60:5.1f} min  ||u|| = {norm(u):.4e}  ||eta|| = {norm(eta):.4e}")
# Out:
# t =   0.0 min  ||u|| = 0.0000e+00  ||eta|| = 0.0000e+00
# t =   0.1 min  ||u|| = 7.2774e+02  ||eta|| = 4.2494e+05
# t =   0.2 min  ||u|| = 1.4536e+03  ||eta|| = 4.2420e+05
# t =   0.4 min  ||u|| = 2.1756e+03  ||eta|| = 4.2296e+05
# t =   0.5 min  ||u|| = 2.8920e+03  ||eta|| = 4.2125e+05
# t =   0.6 min  ||u|| = 3.6010e+03  ||eta|| = 4.1908e+05
# t =   0.8 min  ||u|| = 4.3009e+03  ||eta|| = 4.1648e+05
# t =   0.9 min  ||u|| = 4.9902e+03  ||eta|| = 4.1346e+05
# t =   1.0 min  ||u|| = 5.6674e+03  ||eta|| = 4.1006e+05
# t =   1.1 min  ||u|| = 6.3311e+03  ||eta|| = 4.0631e+05
# t =   1.2 min  ||u|| = 6.9803e+03  ||eta|| = 4.0224e+05
# t =   1.4 min  ||u|| = 7.6137e+03  ||eta|| = 3.9789e+05
# t =   1.5 min  ||u|| = 8.2306e+03  ||eta|| = 3.9329e+05
# t =   1.6 min  ||u|| = 8.8300e+03  ||eta|| = 3.8848e+05
# t =   1.8 min  ||u|| = 9.4115e+03  ||eta|| = 3.8350e+05
# t =   1.9 min  ||u|| = 9.9745e+03  ||eta|| = 3.7837e+05
# t =   2.0 min  ||u|| = 1.0519e+04  ||eta|| = 3.7315e+05
# t =   2.1 min  ||u|| = 1.1044e+04  ||eta|| = 3.6785e+05
# t =   2.2 min  ||u|| = 1.1549e+04  ||eta|| = 3.6252e+05
# t =   2.4 min  ||u|| = 1.2036e+04  ||eta|| = 3.5718e+05
# t =   2.5 min  ||u|| = 1.2503e+04  ||eta|| = 3.5187e+05
# t =   2.6 min  ||u|| = 1.2951e+04  ||eta|| = 3.4661e+05
# t =   2.8 min  ||u|| = 1.3380e+04  ||eta|| = 3.4143e+05
# t =   2.9 min  ||u|| = 1.3791e+04  ||eta|| = 3.3634e+05
# t =   3.0 min  ||u|| = 1.4183e+04  ||eta|| = 3.3138e+05
# t =   3.1 min  ||u|| = 1.4557e+04  ||eta|| = 3.2655e+05
# t =   3.2 min  ||u|| = 1.4913e+04  ||eta|| = 3.2188e+05
# t =   3.4 min  ||u|| = 1.5252e+04  ||eta|| = 3.1738e+05
# t =   3.5 min  ||u|| = 1.5574e+04  ||eta|| = 3.1306e+05
# t =   3.6 min  ||u|| = 1.5880e+04  ||eta|| = 3.0894e+05
# t =   3.8 min  ||u|| = 1.6171e+04  ||eta|| = 3.0501e+05
# t =   3.9 min  ||u|| = 1.6446e+04  ||eta|| = 3.0130e+05
# t =   4.0 min  ||u|| = 1.6706e+04  ||eta|| = 2.9779e+05
# t =   4.1 min  ||u|| = 1.6952e+04  ||eta|| = 2.9450e+05
# t =   4.2 min  ||u|| = 1.7185e+04  ||eta|| = 2.9143e+05
# t =   4.4 min  ||u|| = 1.7404e+04  ||eta|| = 2.8858e+05
# t =   4.5 min  ||u|| = 1.7611e+04  ||eta|| = 2.8594e+05
# t =   4.6 min  ||u|| = 1.7806e+04  ||eta|| = 2.8351e+05
# t =   4.8 min  ||u|| = 1.7989e+04  ||eta|| = 2.8130e+05
# t =   4.9 min  ||u|| = 1.8162e+04  ||eta|| = 2.7929e+05
# t =   5.0 min  ||u|| = 1.8324e+04  ||eta|| = 2.7748e+05
# t =   5.1 min  ||u|| = 1.8477e+04  ||eta|| = 2.7586e+05
# t =   5.2 min  ||u|| = 1.8620e+04  ||eta|| = 2.7443e+05
# t =   5.4 min  ||u|| = 1.8754e+04  ||eta|| = 2.7318e+05
# t =   5.5 min  ||u|| = 1.8880e+04  ||eta|| = 2.7210e+05
# t =   5.6 min  ||u|| = 1.8999e+04  ||eta|| = 2.7118e+05
# t =   5.8 min  ||u|| = 1.9110e+04  ||eta|| = 2.7042e+05
# t =   5.9 min  ||u|| = 1.9214e+04  ||eta|| = 2.6981e+05
# t =   6.0 min  ||u|| = 1.9312e+04  ||eta|| = 2.6933e+05
# t =   6.1 min  ||u|| = 1.9404e+04  ||eta|| = 2.6898e+05
# t =   6.2 min  ||u|| = 1.9490e+04  ||eta|| = 2.6876e+05
# t =   6.4 min  ||u|| = 1.9572e+04  ||eta|| = 2.6864e+05
# t =   6.5 min  ||u|| = 1.9648e+04  ||eta|| = 2.6863e+05
# t =   6.6 min  ||u|| = 1.9721e+04  ||eta|| = 2.6871e+05
# t =   6.8 min  ||u|| = 1.9790e+04  ||eta|| = 2.6888e+05
# t =   6.9 min  ||u|| = 1.9855e+04  ||eta|| = 2.6913e+05
# t =   7.0 min  ||u|| = 1.9918e+04  ||eta|| = 2.6945e+05
# t =   7.1 min  ||u|| = 1.9977e+04  ||eta|| = 2.6983e+05
# t =   7.2 min  ||u|| = 2.0035e+04  ||eta|| = 2.7028e+05
# t =   7.4 min  ||u|| = 2.0090e+04  ||eta|| = 2.7077e+05
# t =   7.5 min  ||u|| = 2.0144e+04  ||eta|| = 2.7131e+05
# t =   7.6 min  ||u|| = 2.0196e+04  ||eta|| = 2.7188e+05
# t =   7.8 min  ||u|| = 2.0247e+04  ||eta|| = 2.7249e+05
# t =   7.9 min  ||u|| = 2.0297e+04  ||eta|| = 2.7313e+05
# t =   8.0 min  ||u|| = 2.0347e+04  ||eta|| = 2.7379e+05
# t =   8.1 min  ||u|| = 2.0397e+04  ||eta|| = 2.7447e+05
# t =   8.2 min  ||u|| = 2.0447e+04  ||eta|| = 2.7515e+05
# t =   8.4 min  ||u|| = 2.0497e+04  ||eta|| = 2.7585e+05
# t =   8.5 min  ||u|| = 2.0547e+04  ||eta|| = 2.7655e+05
# t =   8.6 min  ||u|| = 2.0598e+04  ||eta|| = 2.7725e+05
# t =   8.8 min  ||u|| = 2.0650e+04  ||eta|| = 2.7795e+05
# t =   8.9 min  ||u|| = 2.0703e+04  ||eta|| = 2.7864e+05
# t =   9.0 min  ||u|| = 2.0758e+04  ||eta|| = 2.7932e+05
# t =   9.1 min  ||u|| = 2.0813e+04  ||eta|| = 2.7999e+05
# t =   9.2 min  ||u|| = 2.0870e+04  ||eta|| = 2.8065e+05
# t =   9.4 min  ||u|| = 2.0928e+04  ||eta|| = 2.8129e+05
# t =   9.5 min  ||u|| = 2.0988e+04  ||eta|| = 2.8191e+05
# t =   9.6 min  ||u|| = 2.1050e+04  ||eta|| = 2.8252e+05
# t =   9.8 min  ||u|| = 2.1114e+04  ||eta|| = 2.8311e+05
# t =   9.9 min  ||u|| = 2.1179e+04  ||eta|| = 2.8367e+05
# t =  10.0 min  ||u|| = 2.1246e+04  ||eta|| = 2.8422e+05
# t =  10.1 min  ||u|| = 2.1315e+04  ||eta|| = 2.8474e+05
# t =  10.2 min  ||u|| = 2.1386e+04  ||eta|| = 2.8525e+05
# t =  10.4 min  ||u|| = 2.1459e+04  ||eta|| = 2.8573e+05
# t =  10.5 min  ||u|| = 2.1533e+04  ||eta|| = 2.8620e+05
# t =  10.6 min  ||u|| = 2.1610e+04  ||eta|| = 2.8664e+05
# t =  10.8 min  ||u|| = 2.1689e+04  ||eta|| = 2.8707e+05
# t =  10.9 min  ||u|| = 2.1769e+04  ||eta|| = 2.8748e+05
# t =  11.0 min  ||u|| = 2.1852e+04  ||eta|| = 2.8787e+05
# t =  11.1 min  ||u|| = 2.1937e+04  ||eta|| = 2.8825e+05
# t =  11.2 min  ||u|| = 2.2024e+04  ||eta|| = 2.8861e+05
# t =  11.4 min  ||u|| = 2.2113e+04  ||eta|| = 2.8895e+05
# t =  11.5 min  ||u|| = 2.2204e+04  ||eta|| = 2.8928e+05
# t =  11.6 min  ||u|| = 2.2297e+04  ||eta|| = 2.8960e+05
# t =  11.8 min  ||u|| = 2.2392e+04  ||eta|| = 2.8991e+05
# t =  11.9 min  ||u|| = 2.2490e+04  ||eta|| = 2.9020e+05
# t =  12.0 min  ||u|| = 2.2590e+04  ||eta|| = 2.9049e+05
# t =  12.1 min  ||u|| = 2.2693e+04  ||eta|| = 2.9076e+05
# t =  12.2 min  ||u|| = 2.2798e+04  ||eta|| = 2.9102e+05
# t =  12.4 min  ||u|| = 2.2905e+04  ||eta|| = 2.9128e+05
# t =  12.5 min  ||u|| = 2.3015e+04  ||eta|| = 2.9153e+05
# t =  12.6 min  ||u|| = 2.3128e+04  ||eta|| = 2.9176e+05
# t =  12.8 min  ||u|| = 2.3243e+04  ||eta|| = 2.9199e+05
# t =  12.9 min  ||u|| = 2.3361e+04  ||eta|| = 2.9221e+05
# t =  13.0 min  ||u|| = 2.3482e+04  ||eta|| = 2.9242e+05
# t =  13.1 min  ||u|| = 2.3606e+04  ||eta|| = 2.9262e+05
# t =  13.2 min  ||u|| = 2.3732e+04  ||eta|| = 2.9281e+05
# t =  13.4 min  ||u|| = 2.3861e+04  ||eta|| = 2.9300e+05
# t =  13.5 min  ||u|| = 2.3993e+04  ||eta|| = 2.9317e+05
# t =  13.6 min  ||u|| = 2.4127e+04  ||eta|| = 2.9334e+05
# t =  13.8 min  ||u|| = 2.4265e+04  ||eta|| = 2.9350e+05
# t =  13.9 min  ||u|| = 2.4405e+04  ||eta|| = 2.9364e+05
# t =  14.0 min  ||u|| = 2.4547e+04  ||eta|| = 2.9378e+05
# t =  14.1 min  ||u|| = 2.4692e+04  ||eta|| = 2.9391e+05
# t =  14.2 min  ||u|| = 2.4840e+04  ||eta|| = 2.9402e+05
# t =  14.4 min  ||u|| = 2.4990e+04  ||eta|| = 2.9413e+05
# t =  14.5 min  ||u|| = 2.5143e+04  ||eta|| = 2.9423e+05
# t =  14.6 min  ||u|| = 2.5297e+04  ||eta|| = 2.9432e+05
# t =  14.8 min  ||u|| = 2.5454e+04  ||eta|| = 2.9440e+05
# t =  14.9 min  ||u|| = 2.5613e+04  ||eta|| = 2.9447e+05
# t =  15.0 min  ||u|| = 2.5774e+04  ||eta|| = 2.9454e+05
# t =  15.1 min  ||u|| = 2.5936e+04  ||eta|| = 2.9459e+05
# t =  15.2 min  ||u|| = 2.6100e+04  ||eta|| = 2.9464e+05
# t =  15.4 min  ||u|| = 2.6266e+04  ||eta|| = 2.9469e+05
# t =  15.5 min  ||u|| = 2.6433e+04  ||eta|| = 2.9473e+05
# t =  15.6 min  ||u|| = 2.6602e+04  ||eta|| = 2.9476e+05
# t =  15.8 min  ||u|| = 2.6772e+04  ||eta|| = 2.9479e+05
# t =  15.9 min  ||u|| = 2.6942e+04  ||eta|| = 2.9482e+05
# t =  16.0 min  ||u|| = 2.7114e+04  ||eta|| = 2.9484e+05
# t =  16.1 min  ||u|| = 2.7287e+04  ||eta|| = 2.9486e+05
# t =  16.2 min  ||u|| = 2.7461e+04  ||eta|| = 2.9489e+05
# t =  16.4 min  ||u|| = 2.7635e+04  ||eta|| = 2.9491e+05
# t =  16.5 min  ||u|| = 2.7810e+04  ||eta|| = 2.9493e+05
# t =  16.6 min  ||u|| = 2.7986e+04  ||eta|| = 2.9496e+05
# t =  16.8 min  ||u|| = 2.8162e+04  ||eta|| = 2.9499e+05
# t =  16.9 min  ||u|| = 2.8338e+04  ||eta|| = 2.9502e+05
# t =  17.0 min  ||u|| = 2.8516e+04  ||eta|| = 2.9505e+05
# t =  17.1 min  ||u|| = 2.8693e+04  ||eta|| = 2.9509e+05
# t =  17.2 min  ||u|| = 2.8872e+04  ||eta|| = 2.9514e+05
# t =  17.4 min  ||u|| = 2.9050e+04  ||eta|| = 2.9518e+05
# t =  17.5 min  ||u|| = 2.9230e+04  ||eta|| = 2.9524e+05
# t =  17.6 min  ||u|| = 2.9410e+04  ||eta|| = 2.9530e+05
# t =  17.8 min  ||u|| = 2.9590e+04  ||eta|| = 2.9536e+05
# t =  17.9 min  ||u|| = 2.9772e+04  ||eta|| = 2.9543e+05
# t =  18.0 min  ||u|| = 2.9954e+04  ||eta|| = 2.9550e+05
# t =  18.1 min  ||u|| = 3.0137e+04  ||eta|| = 2.9558e+05
# t =  18.2 min  ||u|| = 3.0321e+04  ||eta|| = 2.9567e+05
# t =  18.4 min  ||u|| = 3.0506e+04  ||eta|| = 2.9575e+05
# t =  18.5 min  ||u|| = 3.0693e+04  ||eta|| = 2.9585e+05
# t =  18.6 min  ||u|| = 3.0881e+04  ||eta|| = 2.9594e+05
# t =  18.8 min  ||u|| = 3.1071e+04  ||eta|| = 2.9604e+05
# t =  18.9 min  ||u|| = 3.1262e+04  ||eta|| = 2.9614e+05
# t =  19.0 min  ||u|| = 3.1454e+04  ||eta|| = 2.9624e+05
# t =  19.1 min  ||u|| = 3.1649e+04  ||eta|| = 2.9634e+05
# t =  19.2 min  ||u|| = 3.1845e+04  ||eta|| = 2.9645e+05
# t =  19.4 min  ||u|| = 3.2043e+04  ||eta|| = 2.9655e+05
# t =  19.5 min  ||u|| = 3.2244e+04  ||eta|| = 2.9665e+05
# t =  19.6 min  ||u|| = 3.2446e+04  ||eta|| = 2.9676e+05
# t =  19.8 min  ||u|| = 3.2650e+04  ||eta|| = 2.9686e+05
# t =  19.9 min  ||u|| = 3.2857e+04  ||eta|| = 2.9696e+05
# t =  20.0 min  ||u|| = 3.3066e+04  ||eta|| = 2.9705e+05
# t =  20.1 min  ||u|| = 3.3277e+04  ||eta|| = 2.9715e+05
# t =  20.2 min  ||u|| = 3.3490e+04  ||eta|| = 2.9724e+05
# t =  20.4 min  ||u|| = 3.3705e+04  ||eta|| = 2.9732e+05
# t =  20.5 min  ||u|| = 3.3923e+04  ||eta|| = 2.9741e+05
# t =  20.6 min  ||u|| = 3.4143e+04  ||eta|| = 2.9749e+05
# t =  20.8 min  ||u|| = 3.4365e+04  ||eta|| = 2.9756e+05
# t =  20.9 min  ||u|| = 3.4589e+04  ||eta|| = 2.9763e+05
# t =  21.0 min  ||u|| = 3.4815e+04  ||eta|| = 2.9770e+05
# Solve forward to annotate to tape

# %%
J = 0
u_.assign(u0)
eta_.project(m*eta0)
solutions = [q_.copy(deepcopy=True)]
for i in range(num_timesteps):
    print(f"t = {i*op.dt/60:5.1f} min  ||u|| = {norm(u):.4e}  ||eta|| = {norm(eta):.4e}")
    solver.solve()
    solutions.append(q.copy(deepcopy=True))
    for gauge in gauges:
        op.gauges[gauge]["obs"].assign(op.gauges[gauge]["data"][i+1])
        op.gauges[gauge]["obs_old"].assign(op.gauges[gauge]["data"][i])
    J = J + assemble(J_form)
    q_.assign(q)
J10 = float(J)
print(f"t = {(i+1)*op.dt/60:5.1f} min  ||u|| = {norm(u):.4e}  ||eta|| = {norm(eta):.4e}")
stop_annotating();
# Out:
# t =   0.0 min  ||u|| = 4.9437e+04  ||eta|| = 3.0147e+05
# t =   0.1 min  ||u|| = 1.4555e+03  ||eta|| = 8.4988e+05
# t =   0.2 min  ||u|| = 2.9071e+03  ||eta|| = 8.4839e+05
# t =   0.4 min  ||u|| = 4.3511e+03  ||eta|| = 8.4592e+05
# t =   0.5 min  ||u|| = 5.7839e+03  ||eta|| = 8.4250e+05
# t =   0.6 min  ||u|| = 7.2019e+03  ||eta|| = 8.3816e+05
# t =   0.8 min  ||u|| = 8.6018e+03  ||eta|| = 8.3295e+05
# t =   0.9 min  ||u|| = 9.9804e+03  ||eta|| = 8.2692e+05
# t =   1.0 min  ||u|| = 1.1335e+04  ||eta|| = 8.2012e+05
# t =   1.1 min  ||u|| = 1.2662e+04  ||eta|| = 8.1262e+05
# t =   1.2 min  ||u|| = 1.3961e+04  ||eta|| = 8.0448e+05
# t =   1.4 min  ||u|| = 1.5227e+04  ||eta|| = 7.9578e+05
# t =   1.5 min  ||u|| = 1.6461e+04  ||eta|| = 7.8658e+05
# t =   1.6 min  ||u|| = 1.7660e+04  ||eta|| = 7.7696e+05
# t =   1.8 min  ||u|| = 1.8823e+04  ||eta|| = 7.6699e+05
# t =   1.9 min  ||u|| = 1.9949e+04  ||eta|| = 7.5674e+05
# t =   2.0 min  ||u|| = 2.1037e+04  ||eta|| = 7.4629e+05
# t =   2.1 min  ||u|| = 2.2087e+04  ||eta|| = 7.3570e+05
# t =   2.2 min  ||u|| = 2.3099e+04  ||eta|| = 7.2504e+05
# t =   2.4 min  ||u|| = 2.4072e+04  ||eta|| = 7.1437e+05
# t =   2.5 min  ||u|| = 2.5006e+04  ||eta|| = 7.0374e+05
# t =   2.6 min  ||u|| = 2.5902e+04  ||eta|| = 6.9322e+05
# t =   2.8 min  ||u|| = 2.6761e+04  ||eta|| = 6.8285e+05
# t =   2.9 min  ||u|| = 2.7581e+04  ||eta|| = 6.7268e+05
# t =   3.0 min  ||u|| = 2.8365e+04  ||eta|| = 6.6275e+05
# t =   3.1 min  ||u|| = 2.9113e+04  ||eta|| = 6.5310e+05
# t =   3.2 min  ||u|| = 2.9826e+04  ||eta|| = 6.4376e+05
# t =   3.4 min  ||u|| = 3.0504e+04  ||eta|| = 6.3476e+05
# t =   3.5 min  ||u|| = 3.1149e+04  ||eta|| = 6.2612e+05
# t =   3.6 min  ||u|| = 3.1761e+04  ||eta|| = 6.1787e+05
# t =   3.8 min  ||u|| = 3.2341e+04  ||eta|| = 6.1003e+05
# t =   3.9 min  ||u|| = 3.2891e+04  ||eta|| = 6.0259e+05
# t =   4.0 min  ||u|| = 3.3412e+04  ||eta|| = 5.9558e+05
# t =   4.1 min  ||u|| = 3.3904e+04  ||eta|| = 5.8901e+05
# t =   4.2 min  ||u|| = 3.4369e+04  ||eta|| = 5.8286e+05
# t =   4.4 min  ||u|| = 3.4808e+04  ||eta|| = 5.7715e+05
# t =   4.5 min  ||u|| = 3.5222e+04  ||eta|| = 5.7188e+05
# t =   4.6 min  ||u|| = 3.5612e+04  ||eta|| = 5.6703e+05
# t =   4.8 min  ||u|| = 3.5979e+04  ||eta|| = 5.6260e+05
# t =   4.9 min  ||u|| = 3.6324e+04  ||eta|| = 5.5857e+05
# t =   5.0 min  ||u|| = 3.6649e+04  ||eta|| = 5.5495e+05
# t =   5.1 min  ||u|| = 3.6953e+04  ||eta|| = 5.5172e+05
# t =   5.2 min  ||u|| = 3.7240e+04  ||eta|| = 5.4886e+05
# t =   5.4 min  ||u|| = 3.7509e+04  ||eta|| = 5.4636e+05
# t =   5.5 min  ||u|| = 3.7761e+04  ||eta|| = 5.4420e+05
# t =   5.6 min  ||u|| = 3.7997e+04  ||eta|| = 5.4237e+05
# t =   5.8 min  ||u|| = 3.8219e+04  ||eta|| = 5.4085e+05
# t =   5.9 min  ||u|| = 3.8428e+04  ||eta|| = 5.3962e+05
# t =   6.0 min  ||u|| = 3.8623e+04  ||eta|| = 5.3867e+05
# t =   6.1 min  ||u|| = 3.8807e+04  ||eta|| = 5.3797e+05
# t =   6.2 min  ||u|| = 3.8980e+04  ||eta|| = 5.3751e+05
# t =   6.4 min  ||u|| = 3.9143e+04  ||eta|| = 5.3728e+05
# t =   6.5 min  ||u|| = 3.9297e+04  ||eta|| = 5.3726e+05
# t =   6.6 min  ||u|| = 3.9442e+04  ||eta|| = 5.3742e+05
# t =   6.8 min  ||u|| = 3.9580e+04  ||eta|| = 5.3776e+05
# t =   6.9 min  ||u|| = 3.9711e+04  ||eta|| = 5.3825e+05
# t =   7.0 min  ||u|| = 3.9835e+04  ||eta|| = 5.3890e+05
# t =   7.1 min  ||u|| = 3.9955e+04  ||eta|| = 5.3967e+05
# t =   7.2 min  ||u|| = 4.0069e+04  ||eta|| = 5.4055e+05
# t =   7.4 min  ||u|| = 4.0180e+04  ||eta|| = 5.4154e+05
# t =   7.5 min  ||u|| = 4.0287e+04  ||eta|| = 5.4261e+05
# t =   7.6 min  ||u|| = 4.0392e+04  ||eta|| = 5.4377e+05
# t =   7.8 min  ||u|| = 4.0494e+04  ||eta|| = 5.4499e+05
# t =   7.9 min  ||u|| = 4.0595e+04  ||eta|| = 5.4626e+05
# t =  17.0 min  ||u|| = 5.7031e+04  ||eta|| = 5.9011e+05
# t =  17.1 min  ||u|| = 5.7387e+04  ||eta|| = 5.9018e+05
# t =  17.2 min  ||u|| = 5.7743e+04  ||eta|| = 5.9027e+05
# t =  17.4 min  ||u|| = 5.8101e+04  ||eta|| = 5.9037e+05
# t =  17.5 min  ||u|| = 5.8459e+04  ||eta|| = 5.9047e+05
# t =  17.6 min  ||u|| = 5.8819e+04  ||eta|| = 5.9059e+05
# t =  17.8 min  ||u|| = 5.9180e+04  ||eta|| = 5.9072e+05
# t =  17.9 min  ||u|| = 5.9543e+04  ||eta|| = 5.9086e+05
# t =  18.0 min  ||u|| = 5.9908e+04  ||eta|| = 5.9101e+05
# t =  18.1 min  ||u|| = 6.0274e+04  ||eta|| = 5.9116e+05
# t =  18.2 min  ||u|| = 6.0642e+04  ||eta|| = 5.9133e+05
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/caching.py in __new__(cls, *args, **kwargs)
#     196         try:
# --> 197             return cls._cache_lookup(key)
#     198         except (KeyError, IOError):
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/caching.py in _cache_lookup(cls, key)
#     204     def _cache_lookup(cls, key):
# --> 205         return cls._cache[key]
#     206
#
# KeyError: (140326152701744, 'b9f3b9d497e7e6a33417b771e28632e8', <class 'pyop2.base.GlobalSet'>, False, False, False, <class 'pyop2.base.Arg'>, <Access.WRITE: 2>, (<class 'pyop2.petsc_base.Global'>, dtype('float64'), (1,)), None, False, None, <class 'pyop2.sequential.JITModule'>, 4)
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/compilation.py in get_so(self, jitmodule, extension)
#     274             # Are we in the cache?
# --> 275             return ctypes.CDLL(soname)
#     276         except OSError:
#
# /usr/lib/python3.8/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     372         if handle is None:
# --> 373             self._handle = _dlopen(self._name, mode)
#     374         else:
#
# OSError: /home/joe/software/firedrake-pragmatic/.cache/pyop2/65/8f36522dc46348ea014611b2e683cf.so: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-de75481fccd2> in <module>
#       8     solutions.append(q.copy(deepcopy=True))
#       9     for gauge in gauges:
# ---> 10         op.gauges[gauge]["obs"].assign(op.gauges[gauge]["data"][i+1])
#      11         op.gauges[gauge]["obs_old"].assign(op.gauges[gauge]["data"][i])
#      12     J = J + assemble(J_form)
#
# PETSc/Log.pyx in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# PETSc/Log.pyx in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/adjoint/function.py in wrapper(self, other, *args, **kwargs)
#     109
#     110             with stop_annotating():
# --> 111                 ret = assign(self, other, *args, **kwargs)
#     112
#     113             if annotate:
#
# <decorator-gen-145> in assign(self, expr, subset)
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/utils.py in wrapper(f, *args, **kwargs)
#      71         opts["type_check"] = safe
#      72         try:
# ---> 73             return f(*args, **kwargs)
#      74         finally:
#      75             opts["type_check"] = check
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/function.py in assign(self, expr, subset)
#     396
#     397         from firedrake import assemble_expressions
# --> 398         assemble_expressions.evaluate_expression(
#     399             assemble_expressions.Assign(self, expr), subset)
#     400         return self
#
# PETSc/Log.pyx in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# PETSc/Log.pyx in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# <decorator-gen-133> in evaluate_expression(expr, subset)
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/utils.py in wrapper(f, *args, **kwargs)
#      68         safe = parameters["type_check_safe_par_loops"]
#      69         if check == safe:
# ---> 70             return f(*args, **kwargs)
#      71         opts["type_check"] = safe
#      72         try:
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/assemble_expressions.py in evaluate_expression(expr, subset)
#     495     for kernel, iterset, args in arguments:
#     496         with dereffed(args) as args:
# --> 497             firedrake.op2.par_loop(kernel, subset or iterset, *args)
#     498     return lvalue
#     499
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/base.py in par_loop(kernel, iterset, *args, **kwargs)
#    3817         from pyop2 import pyparloop
#    3818         return pyparloop.ParLoop(kernel, iterset, *args, **kwargs).compute()
# -> 3819     return _make_object('ParLoop', kernel, iterset, *args, **kwargs).compute()
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/base.py in compute(self)
#    3572             iterset = self.iterset
#    3573             arglist = self.arglist
# -> 3574             fun = self._jitmodule
#    3575             # Need to ensure INC globals are zero on entry to the loop
#    3576             # in case it's reused.
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/utils.py in __get__(self, obj, cls)
#      60         if obj is None:
#      61             return self
# ---> 62         obj.__dict__[self.__name__] = result = self.fget(obj)
#      63         return result
#      64
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/sequential.py in _jitmodule(self)
#     204     @cached_property
#     205     def _jitmodule(self):
# --> 206         return JITModule(self.kernel, self.iterset, *self.args,
#     207                          iterate=self.iteration_region,
#     208                          pass_layer_arg=self._pass_layer_arg)
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/caching.py in __new__(cls, *args, **kwargs)
#     197             return cls._cache_lookup(key)
#     198         except (KeyError, IOError):
# --> 199             obj = make_obj()
#     200             cls._cache_store(key, obj)
#     201             return obj
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/caching.py in make_obj()
#     187             # subclass.  But that one should hit the cache and return
#     188             # straight away.
# --> 189             obj.__init__(*args, **kwargs)
#     190             return obj
#     191
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/sequential.py in __init__(self, kernel, iterset, *args, **kwargs)
#      99         self._system_headers = dcopy(type(self)._system_headers)
#     100         if not kwargs.get('delay', False):
# --> 101             self.compile()
#     102             self._initialized = True
#     103
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/sequential.py in compile(self)
#     151         ldargs += self._kernel._ldargs
#     152
# --> 153         self._fun = compilation.load(self,
#     154                                      extension,
#     155                                      self._wrapper_name,
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/compilation.py in load(jitmodule, extension, fn_name, cppargs, ldargs, argtypes, restype, compiler, comm)
#     487         raise CompilationError("Don't know what compiler to use for platform '%s'" %
#     488                                platform)
# --> 489     dll = compiler.get_so(code, extension)
#     490
#     491     fn = getattr(dll, fn_name)
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/compilation.py in get_so(self, jitmodule, extension)
#     302                                             raise subprocess.CalledProcessError(status, cmd)
#     303                                     else:
# --> 304                                         subprocess.check_call(cc, stderr=err,
#     305                                                               stdout=log)
#     306                                 except subprocess.CalledProcessError as e:
#
# /usr/lib/python3.8/subprocess.py in check_call(*popenargs, **kwargs)
#     357     check_call(["ls", "-l"])
#     358     """
# --> 359     retcode = call(*popenargs, **kwargs)
#     360     if retcode:
#     361         cmd = kwargs.get("args")
#
# /usr/lib/python3.8/subprocess.py in call(timeout, *popenargs, **kwargs)
#     338     retcode = call(["ls", "-l"])
#     339     """
# --> 340     with Popen(*popenargs, **kwargs) as p:
#     341         try:
#     342             return p.wait(timeout=timeout)
#
# /usr/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     852                             encoding=encoding, errors=errors)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#     856                                 startupinfo, creationflags, shell,
#
# /usr/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1635                     fds_to_keep = set(pass_fds)
#    1636                     fds_to_keep.add(errpipe_write)
# -> 1637                     self.pid = _posixsubprocess.fork_exec(
#    1638                             args, executable_list,
#    1639                             close_fds, tuple(sorted(map(int, fds_to_keep))),
#
# OSError: [Errno 12] Cannot allocate memory

# %% [markdown]
# Create `ReducedFunctional` and compute gradient using discrete adjoint

# %%
Jhat = ReducedFunctional(J, c)

# %% [markdown]
# Sample control space at two more points

# %%
J2 = Jhat(m.assign(2.0))
J5 = Jhat(m.assign(5.0))

# %%
l = si.lagrange([2, 5, 10], [J2, J5, J10])
dl = l.deriv()
l_min = -dl.coefficients[1]/dl.coefficients[0]
print("Minimiser of quadratic: {:.4f}".format(l_min))

# %% [markdown]
# Plot the parameter space

# %%
fig, axes = plt.subplots(figsize=(8, 8))
xx = np.linspace(2, 10, 100)
axes.plot(xx, l(xx), ':', color='C0')
axes.plot(l_min, l(l_min), '*', markersize=14, color='C0', label=r"$m^\star={:.4f}$".format(l_min))

axes.set_xlabel("Control parameter")
axes.set_ylabel("Quantity of Interest")
axes.grid(True)
axes.legend();

# %% [markdown]
# Minimisers for $\theta=\frac12$: 4.0913, 4.7927, 4.9221.
# Minimisers for $\theta=1$: 4.5361, 4.8471, 4.9342
